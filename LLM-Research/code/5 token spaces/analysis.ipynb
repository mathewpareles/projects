# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def getAccuracy(completion_eqns, expected_completion_eqns, eval_dict):

    spaced_eval_dict = eval_dict
    spaced_keys =spaced_eval_dict.keys()

    eval_dict={}
    for key in spaced_keys:
        eval_dict[key.replace(' ','')] = spaced_eval_dict[key]

    def LHSOfEqn(eqn_str):
        first_equals = eqn_str.find('=')
        LHS = eqn_str[0:first_equals].replace(' ', '')
        return LHS

    def RHSOfEqn(eqn_str):
        last_equals = eqn_str.rfind('=')
        RHS = eqn_str[last_equals+1:].replace(' ', '')
        return RHS

    '''
    metric = value | verbatim
    accuracyType = numCorrectOverTotal | firstIncorrectOverTotal

    ((accuracy[type])[metric]) = a number

    accuracy = {
        numCorrectAcc: {
            value: ...,
            verbatim: ...,
        },
        firstIncorrectAcc: {
            value: ...,
            verbatim: ...,
        }
    }
    '''
    numCorrectAcc = {"value": 0, "verbatim": 0}
    firstIncorrectAcc = {"value": 1, "verbatim": 1}
    _firstIncorrectValNotFound = True
    _firstIncorrectVerbNotFound = True

    num_expected_eqns = len(expected_completion_eqns)
    for i in range(num_expected_eqns):
        expected_eqn = expected_completion_eqns[i]

        try:
            completion_eqn = completion_eqns[i]
        except:
            completion_eqn = ''

        completion_LHS, completion_RHS = LHSOfEqn(
            completion_eqn), RHSOfEqn(completion_eqn)

        try:
            equal_verbatim = (completion_eqn == expected_eqn)
        except:
            equal_verbatim = False

        try:
            equal_value = (eval_dict[completion_LHS]
                           == int(completion_RHS[-2:]))
        except:
            equal_value = False

        numCorrectAcc["value"] += int(equal_value) / num_expected_eqns
        numCorrectAcc["verbatim"] += int(equal_verbatim) / num_expected_eqns

        if (not equal_value) and _firstIncorrectValNotFound:
            firstIncorrectAcc["value"] = i / num_expected_eqns
            _firstIncorrectValNotFound = False
        if (not equal_verbatim) and _firstIncorrectVerbNotFound:
            firstIncorrectAcc["verbatim"] = i / num_expected_eqns
            _firstIncorrectVerbNotFound = False

    accuracy = {
        "numCorrectAcc": numCorrectAcc,
        "firstIncorrectAcc": firstIncorrectAcc,
    }

    return accuracy


def averageOfAccuracies(accs):
    acc_avg = {
        "numCorrectAcc": {
            "value": 0,
            "verbatim": 0,
        },
        "firstIncorrectAcc": {
            "value": 0,
            'verbatim': 0,
        }
    }

    for acc in accs:
        for _type in acc.keys():
            for _metric in acc[_type].keys():
                acc_avg[_type][_metric] += acc[_type][_metric] / len(accs)

    return acc_avg


def strToEqns(text):
    _completion_lines = text.split('\n')
    _completion_lines = [eqn.replace('\n', '') for eqn in _completion_lines]
    _eqn_idxs = [i for i, completion_line in enumerate(
        _completion_lines) if '=' in completion_line]
    eqns = [_completion_lines[eqn_idx] for eqn_idx in _eqn_idxs]
    return eqns

# %%
def getACC_OF_HINTLEN(experiments,experiments_config):
    _ACCS_OF_HINTLEN = {}  # HINTLEN_VS_ACC[len] = list of accuracies
    _EXPECTED_ACC_OF_HINTLEN = {}

    num_experiments = len(experiments)
    for i_expt in range(num_experiments):

        trials = experiments[i_expt]
        config = experiments_config[i_expt]

        HINTLEN = int(config.NUM_NAME_HINTS)
        _ACCS_OF_HINTLEN[HINTLEN] = []
        _EXPECTED_ACC_OF_HINTLEN[HINTLEN] = max(float((config.NUM_NAME_HINTS - config.NUM_EQN_HINTS) / (
            config.NUM_VARS-config.NUM_EQN_HINTS)), 0)  # acc if hint correct and rest incorrect

        num_trials = len(trials)
        for i_trial in range(num_trials):
            trial = trials.iloc[i_trial]

            completion_text = trial.completion
            expected_completion_text = trial.expected_completion
            eval_dict = trial.eval_dict

            completion_eqns = strToEqns(completion_text)
            expected_completion_eqns = strToEqns(expected_completion_text)

            _ACC = getAccuracy(completion_eqns, expected_completion_eqns, eval_dict)

            _ACCS_OF_HINTLEN[HINTLEN].append(_ACC)

    return _ACCS_OF_HINTLEN,_EXPECTED_ACC_OF_HINTLEN

# %%
experiments = []
experiments_config = []

for hint_len in range(0, 20+1, 1):
    experiments.append(pd.read_json(
        rf'data/[5]{hint_len}_hints,20_var,model_text-davinci-002.json', orient='records'))
    experiments_config.append(pd.read_json(
        rf'data/[config][5]{hint_len}_hints,20_var,model_text-davinci-002.json', orient='records'))

# %%
accOfLen, expectedAccOfLen = getACC_OF_HINTLEN(experiments,experiments_config)

avgAccOfLen = {}  # accuracy of hint length averaged over all trials

for hintlen in accOfLen.keys():
    avgAccOfLen[hintlen] = averageOfAccuracies(accOfLen[hintlen])

# %%
ACC_TYPES =  ['numCorrectAcc', 'firstIncorrectAcc']
ACC_METRICS = ['verbatim','value']  # 'verbatim' | 'value'


for acc_metric in ACC_METRICS:
    for acc_type in ACC_TYPES:
        xs = avgAccOfLen.keys()
        ys = [avgAccOfLen[key][acc_type][acc_metric] for key in avgAccOfLen.keys()]
        plt.plot(xs,ys, label='text-davinci-002')

        ys_expected = expectedAccOfLen.values()
        plt.plot(xs,ys_expected,label='maximal use of hint')


        plt.xlabel('number of variable name hints')
        plt.ylabel('accuracy')
        plt.title(f'Average accuracy (5 trials each) \ntype={acc_type}; metric={acc_metric}')
        plt.legend()
        plt.show()

# %%
num_experiments = len(experiments)
for i_expt in range(num_experiments):
    trials = experiments[i_expt]
    config = experiments_config[i_expt]

    num_trials = len(trials)
    for i_trial in range(num_trials):
        trial = trials.iloc[i_trial]

        prompt = trial.prompt
        completion_text = trial.completion
        expected_completion_text = trial.expected_completion
        eval_dict = trial.eval_dict


        print('************************************************************************')
        print(prompt+'[START]'+completion_text)
# Out:
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables :
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 8 = +a 5 = +a 1 = +a 3 = +a 4 = +a 9 = +0 = 0
# a 1 = +a 3 = +a 4 = +0 = 0
# a 2 = -a 1 0 = -a 1 8 = -a 1 6 = -a 1 5 = -a 1 1 = -0 = 0
# a 3 = +a 4 = +0 = 0
# a 4 = -a 9 = -0 = 0
# a 5 = -a 1 2 = -a 1 = -a 3 = -a 4 = -0 = 0
# a 9 = -a 8 = -0 = 0
# a 1 0 = -a 1 8 = -a 1 6 = -a 1 5 = -a 1 1 = -0 = 0
# a 1 1 = +a 1 = +0 = 0
# a 1 2 = +a 7 = +a 6 = +1 = 1
# a 1 3 = -a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -0 = 0
# a 1 4 = +a 1 3 = +a 1 9 = +a 1 6 = +a 1 5 = +a 1 1 = +0 = 0
# a 1 5 = -a 1 1 = -0 = 0
# a 1 6 = +1 = 1
# a 1 7 = -a 0 = -0 = 0
# a 1 8 = +a 1 4 = +a 1 3 = +a 1 9 = +a 1 6 = +a 1 5 = +a 1 1 = +0 = 0
# a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -0 = 0
#
# The final output is :
# a 6 = +1
# a 7 = -1
# a 8 = 0
# a 1 = 0
# a 2 = 0
# a 3 = 0
# a 4 = 0
# a 5 = 0
# a 9 = 0
# a 1 0 = 0
# a 1 1 = 0
# a 1 2 = 1
# a 1 3 = 0
# a 1 4 = 0
# a 1 5 = 0
# a 1 6 = 1
# a 1 7 = 0
# a 1 8 = 0
# a 1 9 = 0
#
# */
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables :
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# The final value of the expression is +1.
#
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables :
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +a 1 5 = +(-a 1 0) = +(-(-a 0)) = +(-(+0)) = +0
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +a 1 4 = +(-a 1 9) = +(-(-(+1))) = +(-(-1)) = +1
# a 1 6 = +a 1 4 = +(-a 1 9) = +(-(-(+1))) = +(-(-1)) = +1
# a 3 = +a 5 = +(-a 1 2) = +(-(+0)) = +0
# a 1 0 = -a 0 = -(+1) = -1
# a 1 9 = +a 2 = +a 1 = +a 3 = +a 5 = +(-a 1 2) = +(-(+0)) = +0
# a 5 = -a 1 2 = -(+0) = -0
# a 7 = +a 1 5 = +(-a 1 0) = +(-(-a 0)) = +(-(+0)) = +0
# a 1 = +a 3 = +a 5 = +(-a 1 2) = +(-(+0)) = +0
# a 6 = -a 1 1 = -(-1) = +1
# a 1 5 = -a 1 0 = -(-(-a 0)) = -(-(+0)) = -0
# a 1 4 = -a 1 9 = -(-(+1))) = -(-(-1)) = -(-1) = +1
# a 2 = -a 1 = -(+a 3 = +a 5 = +(-a 1 2) = +(-(+0)) = +0) = -0
# a 1 7 = +a 1 6 = +a 1 4 = +(-a 1 9) = +(-(-(+1))) = +(-(-1)) = +1
# a 1 3 = +a 1 7 = +a 1 6 = +a 1 4 = +(-a 1 9) = +(-(-(+1))) = +(
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables :
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 3 = +a 1 9 = +(+1) 9 = 9
# a 4 = -a 1 2 = -(+1) 2 = -2
# a 5 = +a 2 = +(-1) = -1
# a 6 = -a 4 = -(-2) = 2
# a 7 = +a 6 = +2 = 2
# a 8 = +a 1 8 = +(+1) 8 = 8
# a 9 = +a 1 1 = +(+1) 1 = 1
# a 0 = +a 9 = +1 = 1
# a 1 0 = -a 9 = -1 = -1
# a 1 1 = -a 8 = -8 = -8
# a 1 2 = +a 1 6 = +(+1) 6 = 6
# a 1 3 = -a 7 = -2 = -2
# a 1 4 = +a 1 5 = +(+1) (-1) = -1
# a 1 5 = -a 5 = -(-1) = 1
# a 1 6 = -a 1 0 = -(-1) = 1
# a 1 7 = -a 1 4 = -(-1) = 1
# a 1 8 = -a 1 7 = -1 = -1
# a 1 9 = -a 0 = -1 = -1
#
# The final value of the expression is : -1
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables :
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# The value of the expression is -1.
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 8 = +a 5 = +a 4 = +a 3 = +a 2 = +a 1 = +a 0 = +0 = 0
# a 9 = -a 8 = -0 = 0
# a 1 0 = -a 1 8 = -0 = 0
# a 1 1 = +a 1 = +0 = 0
# a 1 2 = +a 7 = +(-1) = -1
# a 1 3 = -a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -0 = 0
# a 1 4 = +a 1 3 = +0 = 0
# a 1 5 = -a 1 1 = -0 = 0
# a 1 6 = -a 1 5 = -0 = 0
# a 1 7 = -a 0 = -a 1 0 = -0 = 0
# a 1 8 = +a 1 4 = +0 = 0
# a 1 9 = -a 8 = -0 = 0
#
# Evaluating all the variables a 5,...:
# a 5 = -a 1 2 = -(-1) = +1
#
# Evaluating all the variables a 4,...:
# a 4 = -a 9 = -0 = 0
#
# Evaluating all the variables a 3,...:
# a 3 = +a 4 = +0 = 0
#
# Evaluating all the variables a 2,...:
# a 2 = -a 1 0 = -0 = 0
#
# Evaluating all the variables a 1,...:
# a 1 = +a 3 = +0 = 0
#
# Evaluating all the variables a 0,...:
# a 0 = -a 2 = -a 1 = -0 = 0
#
# Evaluating all the variables a,...:
# a = -a 2 = -a 1 = -0 = 0
#
# The final assignment is:
# a = 0
# a 0 = 0
# a 1 = 0
# a 1 0 = 0
# a 1 1 = 0
# a 1 2 = -1
# a 1 3 = 0
# a 1 4 = 0
# a 1 5 = 0
# a 1 6 = 0
# a 1 7 = 0
# a 1 8 = 0
# a 1 9 = 0
# a 2 = 0
# a 3 = 0
# a 4 = 0
# a 5 = +1
# a 6 = +1
# a 7 = -1
# a 8 =
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 8,...:
# a 1 8 = +1
# a 1 9 = -a 1 8 = -(+1) = -1
# a 2 = +a 1 9 = +(-1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +a 1 5 = +(-a 1 0) = -(-a 1 0) = +a 1 0
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +a 1 4 = +a 1 9 = +(-a 1) = -(-a 1) = +a 1
# a 1 6 = +a 1 4 = +a 1 9 = +(-a 1) = -(-a 1) = +a 1
# a 3 = +a 5 = +(-a 1 2) = -(-a 1 2) = +a 1 2
# a 1 0 = -a 0 = -a 1 = -(+a 1) = -a 1
# a 1 9 = +a 2 = +a 1 5 = +(-a 1 0) = -(-a 1 0) = +a 1 0
# a 5 = -a 1 2 = -(+a 1 0) = -a 1 0
# a 7 = +a 1 5 = +(-a 1 0) = -a 1 0
# a 1 = +a 3 = +a 1 2 = +(+a 1 0) = +a 1 0
# a 6 = -a 1 1 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+a 1 0) = -a 1 0
# a 1 4 = -a 1 9 = -(+a 1 0) = -a 1 0
# a 2 = -a 1 = -(+a 1 0) = -a 1 0
# a 1 7 = +a 1 6 = +a 1 = +(+a 1 0) = +a 1 0
# a 1 3 = +a 1 7 = +a 1 = +(+a 1 0) = +a 1 0
#
# Evaluating all the variables a 8,...:
# a 8 = +1
# a 0 = -a 8 = -(+1) = -1
# a 1 = +a 0 = +(-1) = -1
# a 6 = -a 1 = -(-1) = +1
#
# Evaluating all the variables a 7,...:
# a 7
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 3 = +a 1 9 = +(+1) 9 = +9
# a 4 = -a 1 2 = -(+1) 2 = -2
# a 5 = +a 2 = +(-1) = -1
# a 6 = -a 4 = -(-2) = +2
# a 7 = +a 6 = +(+2) = +2
# a 8 = +a 1 8 = +(+1) 8 = +8
# a 9 = +a 1 1 = +(+1) 1 = +1
# a 0 = +a 1 3 = +(+1) 3 = +3
#
# The final value of the expression is:
# +1 -1 +9 -2 -1 +2 +2 +8 +1 +3 = +1
#
# */
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 3,...:
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 8,...:
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 3,...:
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 3,...:
# a 1 3 = -a 9 = -(+1) = -1
#
# Evaluating all the variables a 9,...:
# a 9 = -a 1 6 = -(-1) = +1
#
# Eval
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 8 = +a 5 = +a 3 = +a 4 = +a 9 = +0 = 0
# a 9 = -a 8 = -0 = 0
# a 5 = -a 1 2 = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a 2) = -(a 1 + a
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 9,a 2,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +a 1 5 = +(-a 1) = -a 1
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +a 1 3 = +a 1 7 = +a 1 6 = +(-a 1) = -a 1
# a 1 6 = +a 1 4 = +a 1 9 = +a 2 = +(-a 1) = -a 1
# a 3 = +a 5 = +a 1 0 = +(-a 1) = -a 1
# a 1 0 = -a 0 = -(-a 1) = +a 1
# a 1 9 = +a 2 = +(-a 1) = -a 1
# a 5 = -a 1 2 = -(-a 1) = +a 1
# a 7 = +a 1 5 = +(-a 1) = -a 1
# a 1 = +a 3 = +a 1 0 = +(-a 1) = -a 1
# a 6 = -a 1 1 = -(-1) = +1
# a 1 5 = -a 1 0 = -(-a 1) = +a 1
# a 1 4 = -a 1 9 = -(-a 1) = +a 1
# a 2 = -a 1 = -(-1) = +1
# a 1 7 = +a 1 6 = +(-a 1) = -a 1
# a 1 3 = +a 1 7 = +(-a 1) = -a 1
#
# Evaluating all the variables a 9,a 4,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +a 1 5 = +(-a 1) = -a 1
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +a 1 3 = +a 1 7 = +a 1 6 = +(-a 1) = -a 1
# a 1 6 = +a
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 3 = +a 1 9 = +(+1) 9 = 9
# a 4 = -a 1 2 = -(+1) 2 = -2
# a 5 = +a 2 = +(-1) = -1
# a 6 = -a 4 = -(-2) = 2
# a 7 = +a 6 = +2 = 2
# a 8 = +a 1 8 = +(+1) 8 = 8
# a 9 = +a 1 1 = +(+1) 1 = 1
# a 0 = +a 9 = +1 = 1
#
# The final expression is:
# 1 - 1 + 9 - 2 + (-1) + 2 - 8 + 1 = 1
#
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 1 1 = +a 1 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 3 = +a 4 = +(-1) = -1
# a 2 = -a 1 0 = -(+1) = -1
# a 1 9 = -a 1 6 = -(+1) = -1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 8 = +a 5 = +(+1) = +1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 4 = -a 9 = -(-1) = +1
# a 1 7 = -a 0 = -(+1) = -1
#
# The final value of a 1 7 is -1.
#
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 9,a 2,a 0,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -a 0 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +0 = 0
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +0 = 0
# a 1 6 = +a 1 4 = +0 = 0
# a 3 = +a 5 = +0 = 0
# a 1 0 = -a 0 = -0 = 0
# a 1 9 = +a 2 = +0 = 0
# a 5 = -a 1 2 = -0 = 0
# a 7 = +a 1 5 = +0 = 0
# a 1 = +a 3 = +0 = 0
# a 6 = -a 1 1 = -(-1) = +1
# a 1 5 = -a 1 0 = -0 = 0
# a 1 4 = -a 1 9 = -0 = 0
# a 2 = -a 1 = -0 = 0
# a 1 7 = +a 1 6 = +0 = 0
# a 1 3 = +a 1 7 = +0 = 0
#
# Evaluating all the variables a 9,a 4,a 1 8,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 1 2 = +a 7 = +0 = 0
# a 1 1 = +a 8 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +0 = 0
# a 1 6 = +a 1 4 = +0 = 0
# a 3 = +a 5 = +0 = 0
# a 1 0 = -a 0 = -0 = 0
# a 1 9 = +a 2 = +0 = 0
# a 5 = -a 1 2 = -0 = 0
# a 7 = +a 1 5 = +0 = 0
# a 1 = +a 3 = +0 = 0
# a 6 = -a 1 1 = -(-1) = +1
# a 1 5 = -a 1 0 = -0 = 0
# a 1 4 = -a 1 9 = -0 = 0
# a 2 = -a
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 6 = -a 4 = -(+1) = -1
# a 7 = +a 6 = +(-1) = -1
# a 8 = +a 1 8 = +(+1) 8 = 8
# a 9 = -a 0 = -(+1) = -1
# a 0 = +a 1 3 = +(+1) 3 = 3
# a 1 0 = -a 9 = -(-1) = 1
# a 1 2 = +a 1 6 = +(+1) 6 = 6
# a 1 3 = -a 7 = -(-1) = 1
# a 1 4 = +a 1 5 = +(+1) (-1) = -1
# a 1 5 = -a 5 = -(-1) = 1
# a 1 6 = -a 1 0 = -(+1) = -1
# a 1 7 = -a 1 4 = -(-1) = 1
# a 1 8 = -a 1 7 = -(-1) = 1
# a 1 9 = -a 0 = -(+1) = -1
# a 3 = +a 1 9 = +(-1) = -1
# a 4 = -a 1 2 = -(+1) 2 = -2
# a 0 = +a 1 3 = +(+1) 3 = 3
#
# Evaluating all the variables a 1,a 2,a 5,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 6 = -a 4 = -(+1) = -1
# a 7 = +a 6 = +(-1) = -1
# a 8 = +a 1 8 = +(+1) 8 = 8
# a 9 = -a 0 = -(+1) = -1
# a 0 = +a 1 3 = +(+1) 3 = 3
# a 1 0 = -a 9 = -(-1) = 1
# a 1 2 = +a 1 6 = +(+1) 6 = 6
# a 1 3 = -a 7 = -(-1) = 1
# a 1 4 = +a 1 5 = +(+1) (-1) =
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 1 1 = +a 1 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 1 = +a 3 = +a 4 = +(+1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 2 = -a 1 0 = -a 1 = -(+1) = -1
# a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -(+1) = -1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 8 = +a 5 = +(+1) = +1
# a 6 = +1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 4 = -a 9 = -(-1) = +1
# a 1 7 = -a 0 = -a 1 = -(+1) = -1
#
# The final value of a 1 7 is -1.
#
# */
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 7 = -a 1 2 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +0 = 0
# a 1 6 = +a 1 4 = +0 = 0
# a 3 = +a 5 = +0 = 0
# a 1 0 = -a 0 = -0 = 0
# a 1 9 = +a 2 = +0 = 0
# a 5 = -a 1 2 = -0 = 0
# a 7 = +a 1 5 = +0 = 0
# a 1 = +a 3 = +0 = 0
# a 6 = -a 1 1 = -0 = 0
# a 1 5 = -a 1 0 = -0 = 0
# a 1 4 = -a 1 9 = -0 = 0
# a 2 = -a 1 = -0 = 0
# a 1 7 = +a 1 6 = +0 = 0
# a 1 3 = +a 1 7 = +0 = 0
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 0 = +a 6 = +0 = 0
# a 1 6 = +a 1 4 = +0 = 0
# a 3 = +a 5 = +0 = 0
# a 1 0 = -a 0 = -0 = 0
# a 1 9 = +a 2 = +0 = 0
# a 5 = -a 1 2 = -0 = 0
# a 7 = +a 1 5 = +0 = 0
# a 1 = +a 3 = +0 = 0
# a 6 = -a 1 1 = -0 = 0
# a 1 5 = -a 1 0 = -0 = 0
# a 1 4 = -a 1 9 = -0 = 0
# a 2 = -a 1 = -0 = 0
# a 1 7 = +a 1 6 = +0 = 0
# a 1 3 = +a 1 7 = +0 = 0
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,...:
# a 9 = +
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = +a 10 = +a 5*a 2 = +(-1)*(-1) = +1
# a 14 = +a 13 = +a 6*a 2 = +a 2*a 2 = +(-1)*(-1) = +1
# a 13 = +a 12 = +a 6*a 2 = +a 2*a 2 = +(-1)*(-1) = +1
# a 12 = +a 11 = +a 6*a 2 = +a 2*a 2 = +(-1)*(-1) = +1
# a 11 = +a 10 = +a 6*a 2 = +a 2*a 2 = +(-1)*(-1) = +1
# a 10 = +a 9 = +a 6*a 2 = +a 2*a 2 = +(-1)*(-1) = +1
# a 9 = +a 8 = +a 1*a 2 = +(+1)*(-1) = -1
# a 8 = +a 7 = +a 1*a 2 = +(+1)*(-1) = -1
# a 7 = +a 6 = +a 1*a 2 = +(+1)*(-1) = -1
# a 6 = +a 5 = +a 1*a 2 = +(+1)*(-1) = -1
# a 5 = +a 4 = +a 1*a 2 = +(+1)*(-1) = -1
# a 4 = +a 3 = +a 1*a 2 = +(+1)*(-1) = -1
# a 3 = +a 2 = +a 1*a 2 = +(+1)*(-1) = -1
# a 2 = +a 1 = +a 1*a 2 = +(+1)*(-1) = -1
# a 1 = +1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = +a 10 = +a 5*a 2 = +(-1)*(-1) = +1
# a 14
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
#
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 1 = +a 3 = +a 4 = +(+1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 2 = -a 1 0 = -a 1 = -(+1) = -1
# a 1 9 = -a 1 6 = -a 1 = -(+1) = -1
# a 1 5 = -a 1 1 = -a 1 = -(+1) = -1
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 1 = +a 3 = +a 4 = +(+1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 2 = -a 1 0 = -a 1 = -(+1) = -1
# a 1 9 = -a 1 6 = -a 1 = -(+1) = -1
# a 1 5 = -a 1 1 = -a 1 = -(+1) = -1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 4 = -a 9 = -(-1) = +1
# a 1 7 = -a 0 = -a 1 = -(+1) = -1
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,...:
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0 = +a 6 = +(+1) = +1
# a 1 3 = -a 1 0 = -(+1) = -1
# a 3 = -a 1 3 = -(-1) = +1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +(+1) = +1
# a 1 6 = -a 1 5 = -(+1) = -1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(-1) = -1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0 = +a 6 = +(+1) = +1
# a 1 3 = -a 1 0 = -(+1) = -1
# a 3 =
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 1 0 = -a 0 = -(+1) = -1
# a 1 9 = +a 2 = +(+1) = +1
# a 5 = -a 1 2 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 5 = -a 1 0 = -(-1) = +1
# a 1 4 = -a 1 9 = -(+1) = -1
# a 2 = -a 1 = -(+1) = -1
# a 1 7 = +a 1 6 = +(-1) = -1
# a 1 3 = +a 1 7 = +(-1) = -1
#
# The final value of a 1 3 is -1.
#
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(+1) = +1
# a 5 = -1
# a 15 = +1
# a 14 = +1
# a 13 = +1
# a 12 = +1
# a 11 = +1
# a 10 = +1
# a 9 = +1
# a 8 = +1
# a 7 = +1
# a 6 = +1
# a 5 = -1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(+1) = +1
# a 5 = -1
# a 15 = +1
# a 14 = +1
# a 13 = +1
# a 12 = +1
#
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) =
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
#
# Evaluating all the variables a 0,a 1,a 3,a 4,a 2,a 1 0,...:
# a 0 = -a 2 = -(+1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 4 = -a 9 = -(-1) = +1
# a 2 = -a 1 0 = -(-1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 1,a 1 3,a 1 4,a 1 5,a 1 6,a 1 7,...:
# a 1 1 = +a 1 = +(+1) = +1
# a 1 3 = -a 1 9 = -(+1) = -1
# a 1 4 = +a 1 3 = +(-1) = -1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 7 = -a 0 = -(-1) = +1
#
# Evaluating all the variables a 1 8,a 1 9,...:
# a 1 8 = +a 1 4 = +(-1) = -1
# a 1 9 = -a 8 = -(+1) = -1
#
# The final assignment of variables is:
# a 0 = -1
# a 1 = +1
# a 2 = +1
# a 3 = +1
# a 4 = +1
# a 5 = +1
# a 6 = +1
# a 7 = -1
# a 8 = +1
# a 9 = -1
# a 1 0 = -1
# a 1 1 = +1
# a 1 2 = -1
# a 1 3 = -1
# a 1 4 = -1
# a 1 5 = -1
# a 1 6 = +1
# a 1 7 = +1
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -(-a 1 2) = +a 1 2
# a 7 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 4 = -a 7 = -(-a 1 4) = +a 1 4
# a 7 = -a 1 4 = -(+a 1 4) = -a 1 4
# a 1 2 = +a 1 4 = +(-a 1 2) = -a 1 2
# a 1 4 = -a 1 2 = -(+a 1 4) = -a 1 4
# a 1 2 = +a 1 4 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(-a 1 2) = +a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
# a 1 2 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 2 = +a 1 2 = +(-(+a 1 2)) = -(+a 1 2) = -a 1 2
#
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 0 = -a 0 = -(+1) = -1
# a 1 9 = +a 2 = +(+1) = +1
# a 5 = -a 1 2 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 1 6 = +a 1 4 = +(-1) = -1
# a 3 = +(+1) = +1
# a 1 2 = +a 7 = +(-1) = -1
# a 1 1 = +a 8 = +(+1) = +1
# a 0 = +a 6 = +(-1) = -1
# a 1 5 = -a 1 0 = -(-1) = +1
# a 1 4 = -a 1 9 = -(+1) = -1
# a 2 = -a 1 = -(+1) = -1
# a 1 7 = +a 1 6 = +(-1) = -1
# a 1 3 = +a 1 7 = +(-1) = -1
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 0 = -a 0 = -(+1) = -1
# a 1 9 = +a 2 = +(+1) = +1
# a 5 = -a 1 2 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(+1) = +1
# a 5 = +a 4 = +(+1) = +1
# a 4 = +a 3 = +(+1) = +1
# a 3 = +a 2 = +(-1) = -1
# a 2 = -a 1 = -(+1) = -1
# a 1 = +1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(+1) = +1
# a 5 = +a 4 = +(+1) = +1
# a 4 = +a 3 = +(+1) =
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
#
# Evaluating all the variables a 3,a 1 1,a 1 0,a 1 6,a 1 5,a 1 7,...:
# a 3 = +a 4 = +(+1) = +1
# a 1 1 = +a 1 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 1 6 = -a 1 5 = -(+1) = -1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 1 7 = -a 0 = -(+1) = -1
#
# Evaluating all the variables a 2,a 1 9,a 1 3,a 1 4,a 1 8,...:
# a 2 = -a 1 0 = -(-1) = +1
# a 1 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 1 9 = -(+1) = -1
# a 1 4 = +a 1 3 = +(-1) = -1
# a 1 8 = +a 1 4 = +(-1) = -1
#
# Evaluating all the variables a 1,...:
# a 1 = +a 3 = +(+1) = +1
#
# Evaluating all the variables a 0,...:
# a 0 = -a 2 = -(+1) = -1
#
# Evaluating all the variables a,...:
# a = -a 2 = -(+1) = -1
#
# The final value of a is -1.
#
# */
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -a 1 2 = +1
# a 7 = -a 1 2 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
# a 3 = -a 1 3 = -(+1) = -1
# a 9 = -a 1 = -(+1) = -1
# a 1 5 = +a 8 = +a 1 5 = +1
# a 1 6 = -a 1 5 = -(+1) = -1
# a 1 2 = -a 0 = -(+1) = -1
# a 1 = +a 1 6 = +(-1) = -1
# a 5 = +a 9 = +(-1) = -1
# a 1 1 = -a 5 = -(-1) = +1
# a 1 8 = +a 1 1 = +(+1) = +1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -a 1 2 = +1
# a 7 = -a 1 2 = -(+1) = -1
# a 1 4 = -a 7 = -(-1) = +1
# a 4 = +a 1 4 = +(+1) = +1
# a 1 7 = -a 4 = -(+1) = -1
# a 6 = +a 1 7 = +(-1) = -1
# a 1 0 = +a 6 = +(-1) = -1
# a 1 3 = -a 1 0 = -(-1) = +1
#
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 6 = +a 1 4 = +(+1) = +1
# a 3 = +a 5 = +(+1) = +1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 9 = +a 2 = +(+1) = +1
# a 5 = -a 1 2 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 6 = -a 1 = -(+1) = -1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 1 4 = -a 1 9 = -(+1) = -1
# a 2 = -a 1 = -(+1) = -1
# a 1 7 = +a 1 6 = +(+1) = +1
# a 1 3 = +a 1 7 = +(+1) = +1
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 6 = +a 1 4 = +(+1) = +1
# a 3 = +a 5 = +(+1) = +1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 9 = +a 2 = +(+1) =
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(-1) = -1
# a 5 = +a 4 = +(+1) = +1
# a 4 = +a 3 = +(+1) = +1
# a 3 = +a 2 = +(-1) = -1
# a 2 = -a 1 = -(+1) = -1
# a 1 = +1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = +a 13 = +(+1) = +1
# a 13 = +a 12 = +(+1) = +1
# a 12 = +a 11 = +(+1) = +1
# a 11 = +a 10 = +(+1) = +1
# a 10 = +a 9 = +(+1) = +1
# a 9 = +a 8 = +(+1) = +1
# a 8 = +a 7 = +(+1) = +1
# a 7 = +a 6 = +(+1) = +1
# a 6 = +a 5 = +(-1) = -1
# a 5 = +a 4 = +(+1) = +1
# a 4 = +a 3 = +(+1
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,a 3,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 2 = -a 1 0 = -a 1 8 = -a 1 4 = -a 1 3 = -a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -a 1 = -a 3 = -(+1) = -1
# a 1 1 = +a 1 = +a 3 = +(+1) = +1
# a 1 9 = -a 1 6 = -a 1 5 = -a 1 1 = -a 1 = -a 3 = -(+1) = -1
# a 1 5 = -a 1 1 = -a 1 = -a 3 = -(+1) = -1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 0 = -a 2 = -(-1) = +1
# a 7 = -a 6 = -(+1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 1 1 = +a 1 = +a 3 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 1 = +a 3 = +(+1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 2 = -a 1 0 = -a 1 8 = -a 1 4 = -a 1 3 = -a 1 9 = -a 1 6 = -a 1 5 = -a 1 1
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -(-a 1 2) = +a 1 2
# a 7 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 4 = -a 7 = -(-a 1 4) = +a 1 4
# a 4 = +a 1 4 = +(-a 1 4) = -a 1 4
# a 1 7 = -a 4 = -(+a 1 7) = -a 1 7
# a 6 = +a 1 7 = +(-a 1 7) = -a 1 7
# a 1 0 = +a 6 = +(-a 1 0) = -a 1 0
# a 1 3 = -a 1 0 = -(+a 1 3) = -a 1 3
# a 3 = -a 1 3 = -(-(+a 3)) = +a 3
# a 9 = -a 1 = -(+a 9) = -a 9
# a 1 5 = +a 8 = +(+a 1 5) = +a 1 5
# a 1 6 = -a 1 5 = -(+a 1 6) = -a 1 6
# a 1 2 = -a 0 = -(+a 1 2) = -a 1 2
# a 1 = +a 1 6 = +(-(+a 1)) = -a 1
# a 5 = +a 9 = +(+a 5) = +a 5
# a 1 1 = -a 5 = -(+a 1 1) = -a 1 1
# a 1 8 = +a 1 1 = +(-(+a 1 8)) = -a 1 8
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 7 = -(-a 1 2) = +a 1 2
# a 7 = -a 1 2 = -(+a 1 2) = -a 1 2
# a 1 4 = -a 7 = -(-a 1 4) = +a 1 4
#
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,a 1 0,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# ...
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 3 = +a 5 = +(+1) = +1
# a 1 = +a 3 = +(+1) = +1
# a 2 = -a 1 = -(+1) = -1
# a 1 9 = +a 2 = +(-1) = -1
# a 1 4 = -a 1 9 = -(-1) = +1
# a 1 6 = +a 1 4 = +(+1) = +1
# a 1 7 = +a 1 6 = +(+1) = +1
# a 1 3 = +a 1 7 = +(+1) = +1
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,a 1 0,a 1 5,a 7,a 1 2,a 5,a 3,a 1,a 2,a 1 9,a 1 4,a 1 6,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,a 8,a 1 1,a 9,a 1 0,a 1 6,a 1 2,a 4,a 6,a 7,a 1 3,a 0,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = -a 14 = -(+a 5) = -(-1) = 1
# a 14 = +a 15 = +(+1) = +1
# a 17 = -a 16 = -(+a 14) = -(+1) = -1
# a 18 = -a 17 = -(-(+1)) = -(-1) = 1
# a 8 = +a 18 = +(+1) = +1
# a 11 = -a 10 = -(+a 8) = -(+1) = -1
# a 9 = +a 11 = +(-1) = -1
# a 10 = +a 9 = +(-1) = -1
# a 16 = +a 10 = +(-1) = -1
# a 6 = -a 4 = -(+a 16) = -(-1) = 1
# a 4 = +a 6 = +(+1) = +1
# a 13 = -a 12 = -(+a 6) = -(+1) = -1
# a 12 = +a 13 = +(-1) = -1
# a 3 = +a 12 = +(-1) = -1
# a 0 = +a 3 = +(-1) = -1
# a 7 = +a 6 = +(+1) = +1
# a 3 = -a 7 = -(+1) = -1
# a 5 = -a 3 = -(-(+1)) = -(-1) = 1
# a 1 = -a 5 = -(+1) = -1
# a 1 = +a 1 = +(-1) = -1
# a 1 = +1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,a 8,a 1 1,a 9,a 1 0,a 1 6,a 1 2,a 4,a 6,a 7,a 1 3,a 0,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = -a 14 = -(+a 5) = -(-
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +a 5 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +a 5 = +(
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,a 3,a 1,a 1 1,a 1 5,a 1 6,a 1 9,a 1 3,a 1 4,a 1 8,a 1 0,a 2,a 0,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 1 = +a 3 = +(+1) = +1
# a 1 1 = +a 1 = +(+1) = +1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 9 = -a 1 6 = -(+1) = -1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 2 = -a 1 0 = -(-1) = +1
# a 0 = -a 2 = -(+1) = -1
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,a 3,a 1,a 1 1,a 1 5,a 1 6,a 1 9,a 1 3,a 1 4,a 1 8,a 1 0,a 2,a 0,...:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 1 = +a 3 = +(+1) = +1
# a 1 1 = +a 1 =
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,a 6,a 1 0,a 1 3,a 3,a 8,a 1 5,a 1 6,a 1,a 9,a 5,a 1 1,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0 = +a 6 = +(+1) = +1
# a 1 3 = -a 1 0 = -(+1) = -1
# a 3 = -a 1 3 = -(-1) = +1
# a 8 = -a 3 = -(+1) = -1
# a 1 5 = +a 8 = +(-1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 = +a 1 6 = +(+1) = +1
# a 5 = +a 1 = +(+1) = +1
# a 1 1 = -a 5 = -(+1) = -1
# a 1 8 = +a 1 1 = +(-1) = -1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,a 6,a 1 0,a 1 3,a 3,a 8,a 1 5,a 1 6,a 1,a 9,a 5,a 1 1,...:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0 = +a
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,a 1 0,a 1 5,a 7,a 1 2,a 5,a 3,a 1,a 2,a 1 9,a 1 4,a 1 6,a 1 7,...:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 2 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(+1) = -1
# a 3 = +a 5 = +(-1) = -1
# a 1 = +a 3 = +(-1) = -1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 1 = +a 8 = +(+1) = +1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(-1) = -1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 1 = +a 8 = +(+1) = +1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(-1) = -1
# a 6 = -a 1 1 = -(+1) = -1
# a 1 1 = +a 8 = +(+1) = +1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 = +a 3 = +(-1) = -1
# a 6 = -a 1 1 = -
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,a 8,a 1 1,a 9,a 1 0,a 1 6,a 1 2,a 4,a 6,a 7,a 1 3,a 0,a 1 9,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = -a 14 = -(+1) = -1
# a 14 = +a 15 = +(-1) = -1
# a 17 = -a 16 = -(+1) = -1
# a 16 = +a 17 = +(-1) = -1
# a 18 = -a 8 = -(+1) = -1
# a 8 = +a 18 = +(-1) = -1
# a 11 = -a 10 = -(+1) = -1
# a 10 = +a 11 = +(-1) = -1
# a 12 = -a 9 = -(+1) = -1
# a 9 = +a 12 = +(-1) = -1
# a 13 = -a 0 = -(+1) = -1
# a 0 = +a 13 = +(-1) = -1
# a 6 = -a 4 = -(+1) = -1
# a 4 = +a 6 = +(-1) = -1
# a 7 = +a 6 = +(-1) = -1
# a 3 = +a 11 = +(-1) = -1
# a 1 = +1
#
# Evaluating all the variables a 1,a 2,a 5,a 15,a 14,a 17,a 16,a 18,a 11,a 10,a 12,a 9,a 13,a 0,a 6,a 4,a 7,a 3,...:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# a 5 = +a 2 = +(-1) = -1
# a 15 = -a 14 = -(+1) = -1
# a 14 = +a 15 = +(-1) = -1
# a 17 = -a 16 = -(+1) = -1
# a 16 = +a 17 = +(-1) = -1
# a 18 = -a 8 = -(+1) = -1
# a 8 = +a 18 = +(-1) = -1
# a 11 = -a 10 = -(+1) = -1
# a 10 = +a 11 = +(-1) = -1
# a 12 = -a 9 = -
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,a 1 8,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +1
# a 2 = +a 1 1 = +1
# a 1 0 = +a 2 = +1
# a 5 = +a 1 0 = +1
# a 1 = +a 1 2 = +1
# a 1 2 = -a 5 = -1
# a 8 = -a 1 = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +1
# a 1 7 = -a 6 = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,a 1 8,...:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +1
# a 2 = +a 1 1 = +1
# a 1 0 = +a 2 = +1
# a 5 = +a 1 0 = +1
# a 1 = +a 1 2 = +1
# a 1 2 = -a 5 = -1
# a 8 = -a 1 = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +1
# a 1 7 = -a 6 = -1
# a 7 = -a 1 7 = -
# ************************************************************************
# a 0=-a 2
# a 7=-a 6
# a 1 2=+a 7
# a 5=-a 1 2
# a 1 1=+a 1
# a 9=-a 8
# a 1=+a 3
# a 3=+a 4
# a 2=-a 1 0
# a 1 9=-a 1 6
# a 1 5=-a 1 1
# a 8=+a 5
# a 6=+1
# a 1 3=-a 1 9
# a 1 4=+a 1 3
# a 1 8=+a 1 4
# a 1 0=-a 1 8
# a 1 6=-a 1 5
# a 4=-a 9
# a 1 7=-a 0
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,a 3,a 1,a 1 1,a 1 5,a 1 6,a 1 9,a 1 3,a 1 4,a 1 8,a 1 0,a 2,a 0,a 1 7:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# [START]a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 1 = +a 3 = +(+1) = +1
# a 1 1 = +a 1 = +(+1) = +1
# a 1 5 = -a 1 1 = -(+1) = -1
# a 1 6 = -a 1 5 = -(-1) = +1
# a 1 9 = -a 1 6 = -(+1) = -1
# a 1 3 = -a 1 9 = -(-1) = +1
# a 1 4 = +a 1 3 = +(+1) = +1
# a 1 8 = +a 1 4 = +(+1) = +1
# a 1 0 = -a 1 8 = -(+1) = -1
# a 2 = -a 1 0 = -(-1) = +1
# a 0 = -a 2 = -(+1) = -1
# a 1 7 = -a 0 = -(-1) = +1
#
# Evaluating all the variables a 6,a 7,a 1 2,a 5,a 8,a 9,a 4,a 3,a 1,a 1 1,a 1 5,a 1 6,a 1 9,a 1 3,a 1 4,a 1 8,a 1 0,a 2,a 0,a 1 7:
# a 6 = +1
# a 7 = -a 6 = -(+1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 8 = +a 5 = +(+1) = +1
# a 9 = -a 8 = -(+1) = -1
# a 4 = -a 9 = -(-1) = +1
# a 3 = +a 4 = +(+1) = +1
# a 1 = +a
# ************************************************************************
# a 1 9=+1
# a 2=-a 1 9
# a 0=-a 2
# a 8=-a 3
# a 7=-a 1 2
# a 1 4=-a 7
# a 4=+a 1 4
# a 1 7=-a 4
# a 6=+a 1 7
# a 1 0=+a 6
# a 1 3=-a 1 0
# a 3=-a 1 3
# a 9=-a 1
# a 1 5=+a 8
# a 1 6=-a 1 5
# a 1 2=-a 0
# a 1=+a 1 6
# a 5=+a 9
# a 1 1=-a 5
# a 1 8=+a 1 1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,a 6,a 1 0,a 1 3,a 3,a 8,a 1 5,a 1 6,a 1,a 9,a 5,a 1 1,a 1 8:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# [START]a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0 = +a 6 = +(+1) = +1
# a 1 3 = -a 1 0 = -(+1) = -1
# a 3 = -a 1 3 = -(-1) = +1
# a 9 = -a 1 = -(-1) = +1
# a 1 5 = +a 8 = +(+1) = +1
# a 1 6 = -a 1 5 = -(+1) = -1
# a 1 = +a 1 6 = +(-1) = -1
# a 5 = +a 9 = +(+1) = +1
# a 1 1 = -a 5 = -(+1) = -1
# a 1 8 = +a 1 1 = +(-1) = -1
#
# Evaluating all the variables a 1 9,a 2,a 0,a 1 2,a 7,a 1 4,a 4,a 1 7,a 6,a 1 0,a 1 3,a 3,a 8,a 1 5,a 1 6,a 1,a 9,a 5,a 1 1,a 1 8:
# a 1 9 = +1
# a 2 = -a 1 9 = -(+1) = -1
# a 0 = -a 2 = -(-1) = +1
# a 1 2 = -a 0 = -(+1) = -1
# a 7 = -a 1 2 = -(-1) = +1
# a 1 4 = -a 7 = -(+1) = -1
# a 4 = +a 1 4 = +(-1) = -1
# a 1 7 = -a 4 = -(-1) = +1
# a 6 = +a 1 7 = +(+1) = +1
# a 1 0
# ************************************************************************
# a 9=+1
# a 4=-a 9
# a 1 8=+a 4
# a 1 2=+a 7
# a 1 1=+a 8
# a 8=-a 1 8
# a 0=+a 6
# a 1 6=+a 1 4
# a 3=+a 5
# a 1 0=-a 0
# a 1 9=+a 2
# a 5=-a 1 2
# a 7=+a 1 5
# a 1=+a 3
# a 6=-a 1 1
# a 1 5=-a 1 0
# a 1 4=-a 1 9
# a 2=-a 1
# a 1 7=+a 1 6
# a 1 3=+a 1 7
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,a 1 0,a 1 5,a 7,a 1 2,a 5,a 3,a 1,a 2,a 1 9,a 1 4,a 1 6,a 1 7,a 1 3:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# [START]a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -a 1 0 = -(+1) = -1
# a 7 = +a 1 5 = +(-1) = -1
# a 1 2 = +a 7 = +(-1) = -1
# a 5 = -a 1 2 = -(-1) = +1
# a 3 = +a 5 = +(+1) = +1
# a 1 = +a 3 = +(+1) = +1
# a 2 = -a 1 = -(+1) = -1
# a 1 9 = +a 2 = +(-1) = -1
# a 1 4 = -a 1 9 = -(-1) = +1
# a 1 6 = +a 1 4 = +(+1) = +1
# a 1 7 = +a 1 6 = +(+1) = +1
# a 1 3 = +a 1 7 = +(+1) = +1
#
# Evaluating all the variables a 9,a 4,a 1 8,a 8,a 1 1,a 6,a 0,a 1 0,a 1 5,a 7,a 1 2,a 5,a 3,a 1,a 2,a 1 9,a 1 4,a 1 6,a 1 7,a 1 3:
# a 9 = +1
# a 4 = -a 9 = -(+1) = -1
# a 1 8 = +a 4 = +(-1) = -1
# a 8 = -a 1 8 = -(-1) = +1
# a 1 1 = +a 8 = +(+1) = +1
# a 6 = -a 1 1 = -(+1) = -1
# a 0 = +a 6 = +(-1) = -1
# a 1 0 = -a 0 = -(-1) = +1
# a 1 5 = -
# ************************************************************************
# a 8=+a 1 8
# a 2=-a 1
# a 1 9=-a 0
# a 1 7=-a 1 4
# a 1 6=-a 1 0
# a 9=+a 1 1
# a 1 0=-a 9
# a 6=-a 4
# a 1 8=-a 1 7
# a 5=+a 2
# a 1 2=+a 1 6
# a 4=-a 1 2
# a 1 4=+a 1 5
# a 3=+a 1 9
# a 0=+a 1 3
# a 7=+a 6
# a 1 3=-a 7
# a 1 5=-a 5
# a 1 1=-a 8
# a 1=+1
#
# Evaluating all the variables a 1,a 2,a 5,a 1 5,a 1 4,a 1 7,a 1 8,a 8,a 1 1,a 9,a 1 0,a 1 6,a 1 2,a 4,a 6,a 7,a 1 3,a 0,a 1 9,a 3:
# a 1 = +1
# a 2 = -a 1 = -(+1) = -1
# [START]a 5 = +a 2 = +(-1) = -1
# a 15 = -a 14 = -(+1) = -1
# a 14 = +a 15 = +(-1) = -1
# a 17 = -a 16 = -(+1) = -1
# a 16 = +a 17 = +(-1) = -1
# a 18 = -a 15 = -(+1) = -1
# a 15 = +a 18 = +(-1) = -1
# a 9 = +a 1 = +(+1) = +1
# a 10 = -a 9 = -(+1) = -1
# a 6 = -a 4 = -(+1) = -1
# a 4 = +a 6 = +(-1) = -1
# a 3 = +a 10 = +(-1) = -1
# a 0 = +a 3 = +(-1) = -1
# a 7 = +a 6 = +(-1) = -1
# a 6 = -a 7 = -(+1) = -1
# a 3 = -a 0 = -(+1) = -1
# a 10 = +a 3 = +(-1) = -1
# a 9 = -a 10 = -(+1) = -1
# a 18 = +a 9 = +(+1) = +1
# a 15 = -a 18 = -(+1) = -1
# a 1 = -a 2 = -(+1) = -1
# a 2 = +a 1 = +(-1) = -1
# a 5 = -a 1 = -(+1) = -1
# a 1 = +a 5 = +(-1) = -1
# a 15 = +a 14 = +(+1) = +1
# a 14 = -a 15 = -(+1) = -1
# a 17 = +a 16 = +(+1) = +1
# a 16 = -a 17 = -(+1) = -1
#
# The final value of the expression is -1.
# ************************************************************************
# a 1 4=+1
# a 1 9=-a 1 4
# a 1 5=-a 1 9
# a 1 1=+a 1 5
# a 2=+a 1 1
# a 1 0=+a 2
# a 5=+a 1 0
# a 1=+a 1 2
# a 1 2=-a 5
# a 8=-a 1
# a 4=+a 8
# a 0=-a 4
# a 6=+a 0
# a 1 7=-a 6
# a 7=-a 1 7
# a 1 6=-a 7
# a 9=-a 1 6
# a 1 3=-a 9
# a 1 8=-a 1 3
# a 3=-a 1 8
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,a 1 8,a 3:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# [START]a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1) = +1
# a 1 2 = -a 5 = -(+1) = -1
# a 8 = -a 1 = -(+1) = -1
# a 4 = +a 8 = +(-1) = -1
# a 0 = -a 4 = -(-1) = +1
# a 6 = +a 0 = +(+1) = +1
# a 1 7 = -a 6 = -(+1) = -1
# a 7 = -a 1 7 = -(-1) = +1
# a 1 6 = -a 7 = -(+1) = -1
# a 9 = -a 1 6 = -(-1) = +1
# a 1 3 = -a 9 = -(+1) = -1
# a 1 8 = -a 1 3 = -(-1) = +1
# a 3 = -a 1 8 = -(+1) = -1
#
# Evaluating all the variables a 1 4,a 1 9,a 1 5,a 1 1,a 2,a 1 0,a 5,a 1 2,a 1,a 8,a 4,a 0,a 6,a 1 7,a 7,a 1 6,a 9,a 1 3,a 1 8,a 3:
# a 1 4 = +1
# a 1 9 = -a 1 4 = -(+1) = -1
# a 1 5 = -a 1 9 = -(-1) = +1
# a 1 1 = +a 1 5 = +(+1) = +1
# a 2 = +a 1 1 = +(+1) = +1
# a 1 0 = +a 2 = +(+1) = +1
# a 5 = +a 1 0 = +(+1) = +1
# a 1 = +a 1 2 = +(+1
